# %% [markdown]
# # Open Questions
#
# - Are the instructions to vague/specific at some points?
# - How about the amount of tasks? Enough or even too much?

# %% [markdown]
# <div style="text-align: center;" >
# <h1 style="margin-top: 0.2em; margin-bottom: 0.1em;">Introduction to Computation for the Social Sciences</h1>
# <h2 style="margin-top: 0.7em; margin-bottom: 0.3em;">Assignment 1</h2>
# <h3 style="margin-top: 0.7em; margin-bottom: 0.3em;">Deadline: Nov 10, 23:59</h3>
# </div>
# <br>

# %% [markdown]
# <h4 style="margin-top: 0.7em; margin-bottom: 0.3em; font-style:italic">
# Please push your solutions to your personal repository in our <a href='https://classroom.github.com/a/xjo-U8gM'>GitHub Classroom</a></h4><br>
#
# ***

# %% [markdown]
# <h3>Part 1 - GitHub Setup (hurra to you if you already managed during the tutorial session)</h3>

# %% [markdown]
# <h4>Task 1 - Create SSH key pair and add it to your GitHub account</h4>

# %% [markdown]
# - Use your terminal to generate an SSH key pair and add your public key to your GitHub user account. After adding your public SSH key to your GitHub account input the following comand into your terminal: `ssh -T git@github.com`. You should see the message `Hi USERNAME! You've successfully authenticated, but GitHub does notprovide shell access`. If you do, everything works!

# %% [markdown]
# ***Tip:*** If you are struggling with this check out the tutorial notebook (session 01) for detailed instructions.

# %% [markdown]
# <h4>Task 2 - Clone 'ICSS-2023/materials' repository to your machine</h4>

# %% [markdown]
# You should have received two emails from GitHub/us. One containing an invitation to a GitHub Classroom (sender: github-classroom[bot]) and another mail inviting you to the `ICSS-2023/materials` repository (sender: A. R.).<br>
# Pleas open the second email, the one inviting you to `ICSS-2023/materials`, and accept the invitation we sent you. This will give you permission to pull (retrieve) content uploaded to the `ICSS-2023/materials`repository. As you might guess this repository contains the ICSS assignments you will need to complete in this course.

# %% [markdown]
# - Now clone this repository to your local machine. You can find some instructions on how to do that [here](https://docs.github.com/en/repositories/creating-and-managing-repositories/cloning-a-repository).<br>
# ***Tip:*** The instructions here show how to clone a repository using HTTPS. In task 1 you set up your SSH key and your meant to use that in order to clone the repository. See if you can't find a way to clone the repository using SSH instead of HTTPS.

# %% [markdown]
# If you succeded in cloning the repository you should be able to open the directory `assignments` and extract the jupyter notebook containing the additional tasks of this assignment from the folder `a01`.

# %% [markdown]
# <h2>This is not the end of the assignment! Pull (download) the remaining instructions from the 'ICSS-2023/materials' repository</h2>

# %% [markdown]
# <h4>Task 3 - Join our <a href='https://classroom.github.com/a/xjo-U8gM'>GitHub Classroom</a> and clone your personal repository to your machine</h4>

# %% [markdown]
# For this task please open the other email (sender: github-classroom[bot]) which contains an invitation to a so called GitHub Classroom. That will be the place where you hand in your assignment submissions. Please click on the link in the email and join our GitHub Classroom. Upon joining the classroom choose your name and confirm your choice when prompted. This will create a repository named `solutions-yourGitHubUserName`. Clone this repository to your machine using SSH.<br>
#
# ***Note:*** The procedure here is exactly the same as above with the `ICSS-2023/materials` repository. Again, make sure you use SSH to clone the repo and not HTTPS.<br>
#
# Once the repository is cloned to your directory structure you are ready to pull (retrieve remote content from GitHub) and push (upload content to GitHub). Please create a `.txt` file in this (cloned) directory and push it to GitHub. The `.txt`file should contain your first and last name. For the purpose of exercise we encourage you to navigate your directory structure and create the `.txt`file using your terminal.

# %% [markdown]
# ***Tip:*** Use `git add .`, `git commit -m 'first upload'`, and `git push` to upload the `.txt` file. You do not need to post a solution for this particular task here. If your upload to GitHub works as intended your uploaded submission will be solution enough for this task.

# %% [markdown]
# <h4>Task 4 - Establish required directory structure in your solutions repository</h4>

# %% [markdown]
# Now that you have cloned the `ICSS-2023/materials` & your personal `solutions-UserName` repository to your local machine let's make sure your submissions are formatted correctly.<br>
# For that we require you to navigate to your personal `solutions-UserName` repository in your local directory structure. Create a folder called `a01` for your submission of assignment 1. Do so for each upcoming assignemt as well but only once the time to submit them has arrived. For now the folder `a01` will be enough.<br>
# Once you have created the folder `a01` (`submissions-UserName/a01`) navigate to the `ICSS-2023/materials` repository you cloned in task 2 and open the directory `assignments` and then `assignment01`. In there you will find a jupyter notebook (.ipynb) and a PDF version of assignment 1. Copy the jupyter notebook (assignment_01.ipynb) to the folder `a01` you created in your personal `submissions-UserName` repository before.<br>
# To continue working on the assignment and upload it follow these two steps:

# %% [markdown]
# - Open the file `submissions-UserName/a01/assignment_01.ipynb` with jupyter lab and solve the remaining tasks inside the notebook.
# - Once your ready to upload, use `git add .`, `git commit -m 'submission a01'`, and `git push` to upload your solution to GitHub. ***Don't forget to solve the tasks below BEFORE doing this!***

# %% [markdown]
# ***

# %% [markdown]
# <h3>Part 2 - Pandas Data Frames and Data Visualization</h3>

# %% [markdown]
# <h4>Task 5</h4>
# 7 Punkte

# %% [markdown]
# ***a) Import the csv-file on world population***
#
# In the Git Hub, where you pulled the assignment, you were also provided two csv-files. Please import the file on world population and store it as a data frame. Remember to load the pandas library first.

# %%
# Importing packages

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import first data set
pop_data = pd.read_csv("world-population-by-country-2020.csv")

# %% [markdown]
# ***b) Data Types***
#
# Familiarize yourself with the data on world population per country.
#
# Often, it might be useful to rename some columns or change the data type of values.
# Therefore, investigate what data types do the different columns have.

# %%
# Checking data types
pop_data.info()
pop_data.dtypes

# We have object --> all data are string-format
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   no                       235 non-null    int64
#  1   Country (or dependency)  235 non-null    object
#  2   Population 2020          235 non-null    object
#  3   Yearly Change            235 non-null    object
#  4   Net Change               235 non-null    object
#  5   Density  (P/Km²)         235 non-null    object
#  6   Land Area (Km²)          235 non-null    object
#  7   Migrants (net)           201 non-null    object
#  8   Fert. Rate               235 non-null    object
#  9   Med. Age                 235 non-null    object
#  10  Urban Pop %              235 non-null    object
#  11  World Share              235 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 22.2+ KB
# no                          int64
# ...

# %% [markdown]
# Rename the columns using the following dictionary:
#
# `{'no' : 'Nr.', 'Country (or dependency)' : 'Country', 'Population 2020' : 'Population', 'Yearly Change' : 'Yearly_%_Change',
# 'Net Change' : 'Net_Change', 'Density  (P/Km²)' : 'Density', 'Land Area (Km²)' : 'Area', 'Migrants (net)' : 'Net_Migrants',
# 'Fert. Rate' : 'Fert_Rate', 'Med. Age' : 'Median_Age', 'Urban Pop %' : 'Urban_Pop_%', 'World Share' : 'World_Share'}`

# %%
# Renaming columns

pop_data = pop_data.rename(columns = {'no' : 'Nr.', 'Country (or dependency)' : 'Country', 'Population 2020' : 'Population', 'Yearly Change' : 'Yearly_%_Change',
'Net Change' : 'Net_Change', 'Density  (P/Km²)' : 'Density', 'Land Area (Km²)' : 'Area', 'Migrants (net)' : 'Net_Migrants',
'Fert. Rate' : 'Fert_Rate', 'Med. Age' : 'Median_Age', 'Urban Pop %' : 'Urban_Pop_%', 'World Share' : 'World_Share'})

pop_data
# Out:
#      Nr.           Country     Population Yearly_%_Change  Net_Change Density  \
# 0      1             China  1,439,323,776           0.39%   5,540,090     153
# 1      2             India  1,380,004,385           0.99%  13,586,631     464
# 2      3     United States    331,002,651           0.59%   1,937,734      36
# 3      4         Indonesia    273,523,615           1.07%   2,898,047     151
# 4      5          Pakistan    220,892,340           2.00%   4,327,022     287
# ..   ...               ...            ...             ...         ...     ...
# 230  231        Montserrat          4,992           0.06%           3      50
# 231  232  Falkland Islands          3,480           3.05%         103       0
# 232  233              Niue          1,626           0.68%          11       6
# 233  234           Tokelau          1,357           1.27%          17     136
# 234  235          Holy See            801           0.25%           2   2,003
#
# ...

# %% [markdown]
# ***c) Filter out all counties, that have missing values somewhere in the table. Do they contribute a relevant share to the world-population? If not, simply drop these rows (countires)***

# %%
# Filter NA-rows
print(pop_data[pop_data.isnull().any(axis = 1)])

len(pop_data[pop_data.isnull().any(axis = 1)])
# 34 countries, all rather small ones (0% of world pop) --> therefore just drop them
# Out:
#      Nr.                   Country Population Yearly_%_Change Net_Change  \
# 201  202               Isle of Man     85,033           0.53%        449
# 202  203                   Andorra     77,265           0.16%        123
# 203  204                  Dominica     71,986           0.25%        178
# 204  205            Cayman Islands     65,722           1.19%        774
# 205  206                   Bermuda     62,278          -0.36%       -228
# 206  207          Marshall Islands     59,190           0.68%        399
# 207  208  Northern Mariana Islands     57,559           0.60%        343
# 208  209                 Greenland     56,770           0.17%         98
# 209  210            American Samoa     55,191          -0.22%       -121
# 210  211       Saint Kitts & Nevis     53,199           0.71%        376
# 211  212            Faeroe Islands     48,863           0.38%        185
# 212  213              Sint Maarten     42,876           1.15%        488
# ...

# %%
# Drop rows, with NA's
pop_data = pop_data.dropna(axis = 0) 
pop_data
# Out:
#      Nr.              Country     Population Yearly_%_Change  Net_Change  \
# 0      1                China  1,439,323,776           0.39%   5,540,090
# 1      2                India  1,380,004,385           0.99%  13,586,631
# 2      3        United States    331,002,651           0.59%   1,937,734
# 3      4            Indonesia    273,523,615           1.07%   2,898,047
# 4      5             Pakistan    220,892,340           2.00%   4,327,022
# ..   ...                  ...            ...             ...         ...
# 196  197                Aruba        106,766           0.43%         452
# 197  198                Tonga        105,695           1.15%       1,201
# 198  199  U.S. Virgin Islands        104,425          -0.15%        -153
# 199  200           Seychelles         98,347           0.62%         608
# 200  201  Antigua and Barbuda         97,929           0.84%         811
#
#     Density       Area Net_Migrants Fert_Rate Median_Age Urban_Pop_%  \
# ...

# %%
# Here, they need to find out themselves that Urban_Pop_% still contains NaN's (as strings). At least when converting
# to numeric, they will recognize and need to go back here:


# Find index of 'N.A.'- strings:
errors = []

for index, value in enumerate (pop_data['Urban_Pop_%']):
    if value == 'N.A.':
        errors.append(index)
print(errors)
# Out:
# [49, 103, 113, 128, 140, 166, 176]

# %%
# And drop these rows as well

pop_data = pop_data.drop(errors)
pop_data
# Out:
#      Nr.              Country     Population Yearly_%_Change  Net_Change  \
# 0      1                China  1,439,323,776           0.39%   5,540,090
# 1      2                India  1,380,004,385           0.99%  13,586,631
# 2      3        United States    331,002,651           0.59%   1,937,734
# 3      4            Indonesia    273,523,615           1.07%   2,898,047
# 4      5             Pakistan    220,892,340           2.00%   4,327,022
# ..   ...                  ...            ...             ...         ...
# 196  197                Aruba        106,766           0.43%         452
# 197  198                Tonga        105,695           1.15%       1,201
# 198  199  U.S. Virgin Islands        104,425          -0.15%        -153
# 199  200           Seychelles         98,347           0.62%         608
# 200  201  Antigua and Barbuda         97,929           0.84%         811
#
#     Density       Area Net_Migrants Fert_Rate Median_Age Urban_Pop_%  \
# ...

# %% [markdown]
# ***d) Change the data type of all numeric columns. Find a way to deal with the percentage-columns and comma.***

# %%
# Changing data types

repl_comma = ['Population', 'Net_Change', 'Density', 'Area', 'Net_Migrants', 'Median_Age']
repl_perc = ['Yearly_%_Change', 'Urban_Pop_%', 'World_Share']
repl_none = ['Fert_Rate']


def change_data_type(df, col_list, to_repl):
    
    if to_repl == 'comma':
        for col in col_list:
            df[col] = df[col].str.replace(",", "").astype(int) 
            
    elif to_repl == 'percent':
        for col in col_list:
            df[col] = df[col].str.replace("%", "").astype(float) 
    
    elif to_repl == 'none':
        for col in col_list:
            df[col] = df[col].astype(float)
            
    else:
        print("Please specify, what should be replaced")
        
    return df

# %%
pop_data_2 = change_data_type(pop_data, repl_comma, 'comma')
pop_data_2 = change_data_type(pop_data, repl_perc, 'percent')
pop_data_2 = change_data_type(pop_data, repl_none, 'none')

pop_data_2
# Out:
#      Nr.              Country  Population  Yearly_%_Change  Net_Change  \
# 0      1                China  1439323776             0.39     5540090
# 1      2                India  1380004385             0.99    13586631
# 2      3        United States   331002651             0.59     1937734
# 3      4            Indonesia   273523615             1.07     2898047
# 4      5             Pakistan   220892340             2.00     4327022
# ..   ...                  ...         ...              ...         ...
# 196  197                Aruba      106766             0.43         452
# 197  198                Tonga      105695             1.15        1201
# 198  199  U.S. Virgin Islands      104425            -0.15        -153
# 199  200           Seychelles       98347             0.62         608
# 200  201  Antigua and Barbuda       97929             0.84         811
#
#      Density     Area  Net_Migrants  Fert_Rate  Median_Age  Urban_Pop_%  \
# ...

# %%
# ALT.:
# Changing data types

# Get rid of percentage signs and commas to be able to convert columns to int or float
for column in pop_data.columns:
    if pop_data[column].dtype == 'object':
        pop_data[column] = pop_data[column].str.strip('%').str.replace(',', '')

# Specify data type for every column
df = pop_data.astype({
    'Country': 'str',
    'Population': 'int', 
    'Yearly_%_Change': 'float', 
    'Net_Change': 'int', 
    'Density': 'int', 
    'Area': 'int', 
    'Net_Migrants': 'int', 
    'Fert_Rate': 'float', 
    'Median_Age': 'int', 
    'Urban_Pop_%': 'float', 
    'World_Share': 'float' 
})

# Checking data types again
df.dtypes
# Out:
# Nr.                  int64
# Country             object
# Population           int64
# Yearly_%_Change    float64
# Net_Change           int64
# Density              int64
# Area                 int64
# Net_Migrants         int64
# Fert_Rate          float64
# Median_Age           int64
# Urban_Pop_%        float64
# World_Share        float64
# dtype: object

# %% [markdown]
# ***e) Import the second csv-file containing countries, their capital and continent. For nice visualisations later, please merge the information on continents on to your population-data-frame.***
#
# *Hint: use the pandas function `.merge()` and see the documentation [here](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html) for details*.

# %%
# Import second data frame
cap_data = pd.read_csv("countries-continents-capitals.csv", encoding='unicode_escape')
cap_data
# Out:
#      Country/Territory           Capital Continent
# 0          Afghanistan             Kabul      Asia
# 1              Albania            Tirana    Europe
# 2              Algeria           Algiers    Africa
# 3       American Samoa         Pago Pago   Oceania
# 4              Andorra  Andorra la Vella    Europe
# ..                 ...               ...       ...
# 229  Wallis and Futuna          Mata-Utu   Oceania
# 230     Western Sahara         El Aai?§n    Africa
# 231              Yemen             Sanaa      Asia
# 232             Zambia            Lusaka    Africa
# 233           Zimbabwe            Harare    Africa
#
# [234 rows x 3 columns]

# %%
# Merging Data Frames
pop_data_2 = pop_data_2.merge(cap_data[["Country/Territory", "Continent"]],  
               left_on="Country", right_on="Country/Territory").drop(columns= ["Country/Territory"])

pop_data_2
# Out:
#      Nr.              Country  Population  Yearly_%_Change  Net_Change  \
# 0      1                China  1439323776             0.39     5540090
# 1      2                India  1380004385             0.99    13586631
# 2      3        United States   331002651             0.59     1937734
# 3      4            Indonesia   273523615             1.07     2898047
# 4      5             Pakistan   220892340             2.00     4327022
# ..   ...                  ...         ...              ...         ...
# 178  195              Grenada      112523             0.46         520
# 179  197                Aruba      106766             0.43         452
# 180  198                Tonga      105695             1.15        1201
# 181  200           Seychelles       98347             0.62         608
# 182  201  Antigua and Barbuda       97929             0.84         811
#
#      Density     Area  Net_Migrants  Fert_Rate  Median_Age  Urban_Pop_%  \
# ...

# %% [markdown]
# ***f) For some basic descriptive statistics, please find the following countries:***
#
# - *Top 5* countries in absolute population numbers
# - The country with the *highest* population density
# - The counrty with the *highest* and *lowest* yearly %-change

# %%
# 1. sort(descending) and top 5
Top_5 = pop_data_2.sort_values('Population', ascending = False)[0:5][['Country', 'Population']]
Top_5
# Out:
#          Country  Population
# 0          China  1439323776
# 1          India  1380004385
# 2  United States   331002651
# 3      Indonesia   273523615
# 4       Pakistan   220892340

# %%
# 2. max() density
pop_data_2[pop_data_2['Density'] == pop_data_2['Density'].max()]
# Out:
#      Nr.  Country  Population  Yearly_%_Change  Net_Change  Density  Area  \
# 142  152  Bahrain     1701575             3.68       60403     2239   760
#
#      Net_Migrants  Fert_Rate  Median_Age  Urban_Pop_%  World_Share Continent
# 142         47800        2.0          32         89.0         0.02      Asia

# %%
# 3. max() and min() % change

# Hightes %-change
pop_data_2[pop_data_2['Yearly_%_Change'] == pop_data_2['Yearly_%_Change'].max()]
# Out:
#     Nr. Country  Population  Yearly_%_Change  Net_Change  Density     Area  \
# 53   56   Niger    24206644             3.84      895929       19  1266700
#
#     Net_Migrants  Fert_Rate  Median_Age  Urban_Pop_%  World_Share Continent
# 53          4000        7.0          15         17.0         0.31    Africa

# %%
# Lowest %-change --> -0.25
print(pop_data_2[pop_data_2['Yearly_%_Change'] == pop_data_2['Yearly_%_Change'].min()])


# Haben eigentlich gesagt, absolute change 
pop_data_2[pop_data_2["Yearly_%_Change"] == abs(pop_data_2["Yearly_%_Change"]).min()] #lowest
# Out:
#      Nr.    Country  Population  Yearly_%_Change  Net_Change  Density   Area  \
# 132  142  Lithuania     2722289            -1.35      -37338       43  62674
#
#      Net_Migrants  Fert_Rate  Median_Age  Urban_Pop_%  World_Share Continent
# 132        -32780        1.7          45         71.0         0.03    Europe
#      Nr.          Country  Population  Yearly_%_Change  Net_Change  Density  \
# 138  148  North Macedonia     2083374              0.0         -85       83
#
#       Area  Net_Migrants  Fert_Rate  Median_Age  Urban_Pop_%  World_Share  \
# 138  25220         -1000        1.5          39         59.0         0.03
#
#     Continent
# 138    Europe

# %% [markdown]
# ***g) Find the absolute population number, the mean population and %-share among the world-population, when grouping the countires on continent. Save the resulting table into a separate data frame.***

# %%
# Grouping and aggregating

sum_pop = pop_data_2.groupby('Continent')[['Population']].sum().rename(columns={'Population':'Sum_Pop'}).reset_index()
print(sum_pop)

avg_pop = pop_data_2.groupby('Continent')[['Population']].mean().rename(columns={'Population':'Avg_Pop'}).reset_index()
print(avg_pop)

share_pop = pop_data_2.groupby('Continent')[['World_Share']].sum().rename(columns={'World_Share':'Sum_Share'}).reset_index()
print(share_pop)
# Out:
#        Continent     Sum_Pop
# 0         Africa  1307025251
# 1           Asia  4616478773
# 2         Europe   737603587
# 3  North America   587909443
# 4        Oceania    42867268
# 5  South America   402320346
#        Continent       Avg_Pop
# 0         Africa  2.513510e+07
# 1           Asia  1.025884e+08
# 2         Europe  1.891291e+07
# 3  North America  2.672316e+07
# 4        Oceania  3.297482e+06
# 5  South America  3.352670e+07
#        Continent  Sum_Share
# 0         Africa      16.76
# 1           Asia      59.24
# 2         Europe       9.46
# 3  North America       7.55
# 4        Oceania       0.53
# 5  South America       5.16

# %%
continent_df = pd.merge(sum_pop, pd.merge(avg_pop, share_pop, on = "Continent"), on = "Continent")
continent_df
# Out:
#        Continent     Sum_Pop       Avg_Pop  Sum_Share
# 0         Africa  1307025251  2.513510e+07      16.76
# 1           Asia  4616478773  1.025884e+08      59.24
# 2         Europe   737603587  1.891291e+07       9.46
# 3  North America   587909443  2.672316e+07       7.55
# 4        Oceania    42867268  3.297482e+06       0.53
# 5  South America   402320346  3.352670e+07       5.16

# %% [markdown]
# ***h) Plot the absolute population per continent in descending order, using a bar chart. Don't forget to add a header, axis-labels, a legend (if required) and so on.***

# %%
continent_df_sorted = continent_df.sort_values('Sum_Pop', ascending = False)


# fix ledgend
continent_df_sorted["Sum_Pop_Billions"] = continent_df_sorted["Sum_Pop"] / 1_000_000_000

# plot
ax = continent_df_sorted.plot.bar(x="Continent", y="Sum_Pop_Billions", legend=False)

# Add labels and title
ax.set_ylabel("Population (billions)")
ax.set_xlabel("Continent")
ax.set_title("Population by Continent")

plt.show()

# %% [markdown]
# ***i) Visualize the distribution of the continents populations by using a violin plot (if you are not familiar with violin plots, read for example [here](https://mode.com/blog/violin-plot-examples/)). Describe your findings from the two plots in 2 - 3 sentences.***

# %%
# fix y-label
pop_data_2["Population_millions"] = pop_data_2["Population"] / 1_000_000

# plot
plt.figure(figsize=(10,10))
sns.violinplot(
    data=pop_data_2,
    y="Population_millions",
    x="Continent",
    hue="Continent"
)

# labels and title
plt.ylabel("Population (millions)")
plt.xlabel("Continent")
plt.title("Population Distribution by Continent")

# Add line at y=0
plt.axhline(0, color="black", linewidth=1, linestyle="--")

plt.show()

# %% [markdown]
# ***Interprete your plot here:***
#
# - Asia has to biggest outliar in terms of population numbers
# - Africa has second highest sum of population (bar chart) but it's distribution has less extreme outliars (North America and South Ameria have higher ones)
# - Europe has the third highest number of inhabitants, but is very evenly distributed among the countries, it comprises
#
# ARTEFACT: everything below 0 --> not possible (did students comment on/reflect on it - eg by only showing the y-axis over 0)

# %% [markdown]
# <h3>Part 3 - Lambda Functions and List/Dictionary Comprehension</h3>

# %% [markdown]
# <h4>Task 5</h4>
# 5 Points

# %% [markdown]
# ***a) Lambda Functions***
#
# Lambda functions are a handy way to define small, helpful functions. The basic syntax was:
#
# `lambda <parameter>, … : expression`
#
# Use a lambda function to obtain the dictionary representing the person closest to their 50th birthday from a list of dictionaries in the following form (if there are multiple people with the same distance, it is enough to return one):
#
# **3 Punkte**

# %%
people = [{'name': 'Laurie Pineda', 'age': 39}, {'name': 'Tommy Harper', 'age': 21}, 
                    {'name': 'Jeffery Short', 'age': 54}]

people
# Out:
# [{'name': 'Laurie Pineda', 'age': 39},
#  {'name': 'Tommy Harper', 'age': 21},
#  {'name': 'Jeffery Short', 'age': 54}]

# %%
people[0]["age"]
# Out:
# 39

# %%
# Your solution can go here:

# Specify the key-parameter, which declares a function to be applied before the sorting/min/max happens
min(people, key = lambda person: abs(person['age'] - 50))
# Out:
# {'name': 'Jeffery Short', 'age': 54}

# %% [markdown]
# ***b) List Comprehension***
#
# We’ve also learned about list comprehension. Here, the syntax was:
# `L = [<element> for <element> in <list> if <Condition>]`
#
# Use list comprehensions to write a Python function `remove_long_words()` that:
# -	accepts a sentence and an integer n as input parameters
# -	uses the split() function of String objects to split the sentence into words
# -	stores the individual words in a list
# -	removes all words that are longer than n characters from the list, thereby creating a new list
# -	prints the new list
#
#
# **2 Punkte**

# %%
# Your solution can go here:

def remove_long_words(sentence, length): 
    """
    Function for dropping too long words from a sentence
    
    Parameters:
    -------------
    s: sentence to be split into words (string format)
    n: max. number of characters for a word in the sentence (integer format)
    
    Returns:
    -------------
    result: list, storing the words of the input sentence s 
    that are shorter (or equal) in characters than n
    
    """
    
    # Splitting the sentence into a list of words
    word_list = sentence.split()
    
    # Apply list-comprehension, filterin for words <= length
    
    return [word for word in word_list if len(word) <= length]


# Test case
remove_long_words("Hello I am Elena", 3)
# Out:
# ['I', 'am']

# %% [markdown]
# <h4>Task 6</h4>
# 10 Points

# %% [markdown]
# 1) In the GitHub folder for the first assignment, you will find a JSON file containing the US Senate 2022 Midterm Election predictions from fivethirtyeight.com
# -	Open and load the JSON file data into Python
# -	Using list/dictionary comprehension and lambda functions, extract the state-code, name and party affiliation of the candidate with the highest winning probability (winprob) in each state.

# %%
# Your solution can go here:

# Import data

import json
with open('senate_predictions_11_08.json') as f:
    data_pred = json.load(f)
    
#data_pred

# %% [markdown]
# **5 Punkte:**
# * Lambda Funktion um Gewinner zu finden 2 Punkte
# * Wenn (irgendwie) ein Ergebnis bekommen wurde (z.B. mit for-loop) 1 Punkt
# * Wenn alles in List COmprehension ist: 2 Punkte

# %%
# Solution from a student 

prob_win_can = [[y['race'][:2], # extracts the state-code
                 max(y['candidates'], key = lambda x: x['winprob'])['fullname'], 
                 max(y['candidates'], key = lambda x: x['winprob'])['party']]
                for y in data_pred['races']]
#prob_win_can

# %% [markdown]
# 2. Additionally, you can find another JSON file with the (preliminary) US Senate Midterm Election results from “cnn.com”.
# -	Also, open and load this data
# -	Using list/dictionary comprehension and lambda functions, extract the state-code, name and party affiliation of the winner in each state.
# -	Compare the results from the prediction and the result. How many percent of the states were predicted correctly?

# %%
# Your solution can go here:

with open('senate_results_11_10.json') as f:
    data_res = json.load(f)
    
#data_res

# %% [markdown]
# **5 Punkte:**
# * Wenn alles in List Comprehension + mit lambda (same wie in a): 3 Punkte
# * Wenn irgendwie ein Ergebnis bekommen wirde (z.B. mit for-loop) 1 Punkt
# * 1 Punkt wenn man 91% correcte predictions berechnet hat

# %%
# Lösung von einem Studi 

winner = [[y['stateAbbreviation'],
                max(y['candidates'], key=lambda x: float(x['votePercentStr']))['fullName'],
                max(y['candidates'], key=lambda x: float(x['votePercentStr']))['candidatePartyCode']]
                for y in data_res]
#winner

# %%
# merge both lists - tutor solution
## getting the last name is important in order to avoid nonmatch because of different conventions around middle names

prob_win_can = [entry + [entry[1].split()[-1]] for entry in prob_win_can] # get the last names
guess_df = pd.DataFrame(prob_win_can)
guess_df.columns = ["state_code", "candidate", "party", "candidate_lastname"]

winner = [entry + [entry[1].split()[-1]] for entry in winner] # get the last names
winner_df = pd.DataFrame(winner)
winner_df.columns = ["state_code", "candidate", "party", "candidate_lastname"]

merged = pd.merge(guess_df, winner_df, on=["state_code"], how="inner")

# %%
# manually handle OK - there might be a nicer way to that ...
merged = merged[~((merged["state_code"] == "OK") & (merged["candidate_x"] != merged["candidate_y"]))]
merged
# Out:
#    state_code             candidate_x party_x candidate_lastname_x  \
# 0          AK          Lisa Murkowski       R            Murkowski
# 1          AL             Katie Britt       R                Britt
# 2          AR            John Boozman       R              Boozman
# 3          AZ              Mark Kelly       D                Kelly
# 4          CA            Alex Padilla       D              Padilla
# 5          CO          Michael Bennet       D               Bennet
# 6          CT      Richard Blumenthal       D           Blumenthal
# 7          FL             Marco Rubio       R                Rubio
# 8          GA  Herschel Junior Walker       R               Walker
# 9          HI            Brian Schatz       D               Schatz
# 10         IA          Chuck Grassley       R             Grassley
# 11         ID              Mike Crapo       R                Crapo
# 12         IL         Tammy Duckworth       D            Duckworth
# ...

# %%
# add a column for the last name to compare if the prediciton overlaps with the actual winner
merged["correct"] = merged["candidate_lastname_x"] == merged["candidate_lastname_y"]

# %%
# print the prediciton accuracy:

print("Prediction Accuracy (in %):")
round(sum(merged["correct"])/len(merged)*100, 2)
# Out:
# Prediction Accuracy (in %):
# 91.43

# %% [markdown]
# ***

# %% [markdown]
# <h3>Part 4 - Bonus</h3>
# 5 Points

# %% [markdown]
# #### a) 1.5 Punkte
#
# Fehlender Fall n = 0 macht -0.5

# %%
import math

def decimal_int_to_octal(n):
    """
    Function for computing the octal representation of an decimal integer.
    
    Parameters:
    -------------
    n: integer value to be represented in octal notation
    
    Returns:
    -------------
    x_k: a list, storing the digts for the octal representation.
    
    """

    # maybe handle n<0 cases --> error message
    
    # handle n = 0 --> return 0
    
    k = 0     # setting a counter
    x_k = []  # inizializing a list to store the octal representation
    
    
    while n > 0:
        x_k.append(n % 8)
        
        n = math.floor(n/8)
        
        k += 1

    
    
    x_k.reverse() # need to reverse
    
    return x_k

# %% [markdown]
# #### b) 2 Punkte
#
# Fehlendes n=0 --> -0.5
#
#
# Im Optinalfall für n = 0.5 z.b. "0.4" returnen, nicht ".4"

# %%
# Meine Lösung von damals, nicht wirklich clean/schön
# Kritik Aron: Warum return print() statement

def decimal_to_octal(n, digits = 20):
    
    """
    Function for computing the octal representation of an decimal, that can contain decimal digits.
    
    Parameters:
    -------------
    n: value to be represented in octal notation
    digits: the maximum amount of digits the octal representation should have. Default value is 20.
    
    Returns:
    -------------
    octal_representation: list containing the octal representation of the input n
    
    """
    
    # First, the float is separated into the integer part and the decimal places:
    n_str = str(n)
    n_int, n_dec = n_str.split(".")
    
    n_int = int(n_int)  # changing data-type from string to integer
    n_dec = int(n_dec)  # changing data-type from string to integer
    
    # Now we need the decimal digits to be represented in the form "0.xxx". Therefore, we devide the
    # integer-representation of n_dec by 10 to the power of digits, the integer-representation has.
    n_dec = n_dec/(10**(len(str(n_dec))))
    
    
    # We need a list, to store the digits of the octal representation of the decimal-digits part and set a counter
    x_dec_k = []
    k = 0
    
    # Using a loop (with two condition), I will always multiply the n_dec with 8 and store the integer part of it in x_dec_k
    # Afterwards, the new n_dec is the decimal part of the prevoius multiplication with 8
    
    while (n_dec > 0) and (k in range(digits)):
        
        n = int(n_dec * 8)
        x_dec_k.append(n)
        
        n_dec = (n_dec * 8) - int(n_dec * 8)
        
        k += 1
        
        # Note: here, we dont have to invert the order of the resulting list with digits.
    
    
    # For the integer part of the decimal-number that should be converted, we can basically copy the funtion from Exercise 3 a) 
    # Again, we first need a list, to store the digits
    x_int_k = []
    
    while n_int > 0:
        x_int_k.append(n_int % 8)
        n_int = math.floor(n_int/8)
    
    # since the digits are in reverse order, we have to invert the order
    x_int_k.reverse()
    
    
    # merging together the list for the integer-part, a dot to separate the two parts, and the decimal-part
    octal_representation = x_int_k + ["."] + x_dec_k 
    
    return(print(octal_representation))

# %% [markdown]
# #### c) 1.5 Punkte

# %%
# Lösung von einem Studi

def count_bits(n):
    
    """
    Function counts non-zero bits 
    
    Parameters
    ----------
    n: Integer
        Non-negative number
    
    Returns
    -------
    Integer  
        Number of bins  
    
    """
    
    if n >=0: # the function should only work for non-negative values
        x = 0 # create x for the number of bins, with zero counted bins at the beginning 
        while n > 0: # do this loop as long it is larger than zero 
            x = x + (n & 1) # checks if the most right bit is one or zero and if it is one it adds 1 to the count x
            n = n >> 1 # moves n by one bit 
        return x

    else:
        print('This number is not convertable.') # if the number is negative this shows a nice message instead of an error. 
    

# test
print(count_bits(13))
# Out:
# 3
