# %% [markdown]
# <div style="text-align: center;" >
# <h1 style="margin-top: 0.2em; margin-bottom: 0.1em;">Introduction to Computation for the Social Sciences</h1>
# <h2 style="margin-top: 0.7em; margin-bottom: 0.3em;">Assignment 3</h2>
# <h3 style="margin-top: 0.7em; margin-bottom: 0.3em;">Deadline: 21.12.2025 12:00 pm</h3>
#
# </div>
# <br>

# %% [markdown]
# <h4 style="margin-top: 0.7em; margin-bottom: 0.3em; font-style:italic">
# Please push your solutions to your personal repository in our <a href='https://classroom.github.com/classrooms/237719561-icss-2025'>GitHub Classroom</a></h4><br>
#
# ***

# %% [markdown]
# This assignment will test your ability to improve the efficiency and runtime of code, your understanding of sorting algorithms and their complexities, your skills in preprocessing X-Post Data using regular expressions, and finally your ability to build a small Streamlit dashboard.<br>
# As always: In case of questions feel free to reach out to us tutors in person or via mail.<br>
# ***Important: Submit a solution for every single task and do not skip any of them. Even if your solution is not perfect or doesn't work you might still receive some points that way!***

# %% [markdown]
# ***

# %%
# Import the modules you use throughout the assignment here (this is called a setup chunk/cell)
# e.g import pandas as pd
# e.g import numpy as np and so on...

# %% [markdown]
# # Task 1
#
# For this task imagine that you are working in a research group analyzing empirical conflict data (ACLED_South-Sudan_2017.csv).
#
# *Note:* Please use the ``event_date`` column for timestamp and use the Python module ``time`` to **track runtimes**.

# %% [markdown]
# ## Task 1.1
#
# Your supervisor asked you to improve the efficiency of the code. After taking a look at the project’s code you find the sliding_window() function.
# First, add the function description and add comments where it is necessary.

# %%
def sliding_window(data, col_time, col_id, window_size):
   """
   add description of the function 
   """
   # initiate an empty list for the return
   events_intime = []


   for i in range(len(data)):
       event_date = data[col_time].iloc[i]
       events_intime.append([])
      
       for j in range(len(data)):
           other_date = data[col_time].iloc[j]
          
           if abs((event_date - other_date).days) <= window_size and i != j:
               events_intime[i].append(data[col_id].iloc[j])

   return events_intime

# %% [markdown]
# ## Task 1.2
#
# Now think about how you can make this function faster and write a new function `sliding_window_optimized()`, which improves the runtime of the first function.
#
# *Hint*: Consider first sorting the data by timestamp and then checking neighboring events in order to minimize unnecessary comparisons.

# %%
def sliding_window_optimized():
    #Your Code

# %% [markdown]
# ## Task 1.3
#
# Systematically compare the runtime of both functions for different window sizes and visualize you results.
#
# *Hint*: The unoptimized version may run slowly on some machines, so aim to reduce how often you call it.

# %%
# Your Code

# %% [markdown]
# ***
# # Task 2
#
# In this task, the runtime of two sorting-algorithms will be compared. Again, use the `time` package to measure the runtime.

# %% [markdown]
# ## Task 2.1
#
# Implement the Selection Sort algorithm, as learned in the lecture, for a list input.

# %%
# Your Code

# %% [markdown]
# ## Task 2.2
#
# Look up the algorithm behind Python's built-in sorting algorithm (`sorted()`). Describe it briefly in key points.
#
# *Hint*: Python is using an algorithm called 'TimSort'

# %% [markdown]
# Your answer

# %% [markdown]
# ## Task 2.3
#
# Compare the runtime of your own implementation of Selection Sort with the runtime of Python’s built-in sorting algorithm on lists of different lengths (e.g., 1,000; 2,000; 3,000; up to 10,000) containing random integers, and visualize the results.

# %%
# Your Code

# %% [markdown]
# ## Task 2.4
#
# Now test the runtime of (only) Python’s sorted() function on lists ranging from 100,000 to 1,000,000 elements (in steps of 100,000). Test the following input cases:
#
# - a list of random integers
# - a list of integers sorted in descending order
# - a list of integers sorted in ascending order
#
# Again, please visualize the results.

# %%
# Your Code

# %% [markdown]
# ***
# # Part 3 - Preprocessing & Regular Expressions

# %% [markdown]
# In the assignment folder, you will find a `US_politican_tweets_pre_midterm_2022.zip` containing a .json file with tweets of US politicians. The file consists of 171,795 tweets that were tweeted by US politicans in the 5 months prior to the 2022 midterm elections (01.06.2022 - 08.11.2022, the election took place at 08.11.2022).<br>
#
# You will need to process this file aka. the tweets in it in order to work with the data in task 4 and the next assignment.<br>
# ***Hint: Use a sample of tweets in order to test your preprocessing steps before you run them on the whole data set. Make sure that your sample contains tweets with hashtags, otherwise you can not test all of your funtions. Set seeds for reproducibility.***
#
# ## Task 3
#
# In the next assignment you will have to perform sentiment analysis on these tweets. Keeping that in mind please perform the following preprocessing operations on the data. <br>
# First, we will replace user mentions, extract hashtags and remove urls from the original text column
# To do so, you will need to use regular expressions.
#
# Create three functions:
# - `replace_mentions()`: a function that replaces all user mentions (@username) in the text column with '@user' (think of it as anonymizing the data). You are supposed to change the original text column here!
# - `extract_hastags()`: a function that extracts all hashtags (e.g. #MAGA) appearing in the tweet and stores them in a new column `hashtags` without altering the original text column
# - `remove_urls()`: a function that extracts all domain names from the 'expanded_url' field (entities_urls → expanded_url) to a new column (e.g. [google.com, wikipedia.org, ...]) and removes the URLs from the original text colmn.<br>
#
#
#
# Before you get into coding take a moment and think about how you might use regular expressions to solve this task.
# Develop a regular expression for each of the three functions and shortly explain how it works - for example in the comments.

# %% [markdown]
# For this task, you might want to consider the [re module](https://docs.python.org/3/library/re.html).<br>

# %%
# Your code

# %% [markdown]
# ***
# # Part 4 - Application

# %% [markdown]
# ## Task 4.1
#
# Using the Streamlit library, you are asked to develop a dashboard that supports the manual sentiment annotation of tweets. The basis is a random sample of 150 tweets from the `US_politican_tweets_pre_midterm_2022.json`, which you preprocessed in task 3, saved as a .json file. Each entry must include the corresponding tweet_id (column `id`) so that your manual labels can later be compared to other machine generated labels, which we will introduce in assignment 4.
#
# You will need to solve this task in an extra `.py`-file, as Jupyter notebooks do not work very well with streamlit. Don't forget to upload the `.py`-file in your submission repo.
#
# Consider the following (treat is a checklist):
#
# - For labeling, always work with the original text of the tweets. Mentions should appear as @user, URLs should be removed, and hashtags should remain unchanged.
# - The dashboard should sequentially display random, unlabeled tweets and allow you to assign them to one of four categories: positive, negative, neutral, or undecidable.
# - Once a tweet has been labeled, it is removed from the pool and the next unlabeled tweet is automatically shown. Previously labeled tweets must not be displayed again.
# - Another key functionality is the ability to save the current progress. The output file should not only contain tweets labeled during the current session but also those from earlier sessions.
# - The dashboard should be presented with a clear title, an intuitive interface and short notifications or confirmations after important actions (e.g., when saving). While aesthetics are not the main focus, a well-structured and user-friendly design is important.
#
# On the technical side, `st.session_state` and `callbacks` will likely be useful. The titanic_app example from the tutorial may serve as inspiration. All code should be carefully commented so that the process and logic are transparent.
# <br>
#
# ***Hint: There are many ways of solving this task! There is no 'one and only' solution so be bold and experiment with your ideas. You can probably make most of them work!***

# %%
# Your code NOT HERE (-> you need a .py-file)

# %% [markdown]
# ## Task 4.2
#
#
# Use your application to classify your sample of 150 tweets from the preprocessed `US_politican_tweets_pre_midterm_2022.json` data and save your result as 'manually_labeled_tweets.json'.<br>
# Make sure you upload this labeled sample of tweets to your solutions repository!
